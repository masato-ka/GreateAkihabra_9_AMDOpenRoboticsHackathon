# %% [markdown]
# # Train Models Using LeRobot on MI300x
#
# This guide walks you through setting up environment for training imitation learning policies using LeRobot library on a DigitalOcean (DO) instance equipped with AMD MI300x GPUs and ROCm.
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=${HF_USER}/${DATASET_NAME}`).
#   If you don’t have an access token yet, you can sign up for Hugging Face [here](https://huggingface.co/join). After signing up, create an access token by visiting [here](https://huggingface.co/settings/tokens).
# - A wandb account to enable training visualization and upload your training evidence to our github.
#   You can sign up for Wandb [here](https://wandb.ai/signup) and visit [here](https://wandb.ai/authorize) to create a token.
# - Access to DO instance AMD Mi300x GPU

# %% [markdown]
# ## Verify ROCm and GPU availability
# This cell uses `pytorch` to check AMD GPU Info. The expected ouput is
# ```
# CUDA compatible device availability: True
# device name [0]: AMD Instinct MI300X VF
# ```

# %%
import torch
print(f'CUDA compatible device availability:',torch.cuda.is_available())
print(f'device name [0]:', torch.cuda.get_device_name(0))
# Out:
# CUDA compatible device availability: True
# device name [0]: AMD Instinct MI300X VF

# %% [markdown]
# ## Install FFmpeg 7.x
# This cell uses `apt` to install ffmpeg 7.x for LeRobot.

# %%
# !add-apt-repository ppa:ubuntuhandbook1/ffmpeg7 -y # install PPA which contains ffmpeg 7.x
# !apt update && apt install ffmpeg -y
# Out:
# Repository: 'Types: deb
# URIs: https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu/
# Suites: noble
# Components: main
# '
# Description:
# unofficial build for FFmpeg 7 for Ubuntu 22.04 | 24.04, backport from Debian's deb.multimedia.org repository
#
# If the packages here are helpful, you may buy me a coffee:
#
#          https://ko-fi.com/ubuntuhandbook1
# More info: https://launchpad.net/~ubuntuhandbook1/+archive/ubuntu/ffmpeg7
# Adding repository.
# Hit:1 https://repo.radeon.com/amdgpu/30.10/ubuntu jammy InRelease
# Hit:2 https://repo.radeon.com/rocm/apt/7.0 jammy InRelease
# Hit:3 https://repo.radeon.com/graphics/7.0/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu noble InRelease
# Get:5 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease [17.8 kB]
# Get:8 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble InRelease [18.1 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble/main amd64 Packages [40.2 kB]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [1700 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 Packages [7835 B]
# Get:13 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [2059 kB]
# Get:14 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [25.3 kB]
# Get:15 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [1182 kB]
# Get:16 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [90.5 kB]
# Get:17 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [2796 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 Components [235 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [1943 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble-updates/universe amd64 Components [520 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [2929 kB]
# Get:22 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [156 B]
# Get:23 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [33.1 kB]
# Get:24 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [157 B]
# Get:25 http://archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Components [158 B]
# Get:26 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [35.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Components [888 B]
# Get:28 http://archive.ubuntu.com/ubuntu noble-backports/main amd64 Packages [49.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble-backports/main amd64 Components [7885 B]
# Get:30 http://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [34.3 kB]
# Get:31 http://archive.ubuntu.com/ubuntu noble-backports/universe amd64 Components [11.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu noble-backports/restricted amd64 Components [161 B]
# Get:33 http://archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 Components [162 B]
# Fetched 14.1 MB in 2s (7256 kB/s)
# Reading package lists... Done
# Hit:1 https://repo.radeon.com/amdgpu/30.10/ubuntu jammy InRelease
# Hit:2 https://repo.radeon.com/rocm/apt/7.0 jammy InRelease
# Hit:3 https://repo.radeon.com/graphics/7.0/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu noble InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu noble InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 91 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   alsa-topology-conf alsa-ucm-conf libaribb24-0t64 libasound2-data
#   libasound2t64 libass9 libasyncns0 libavc1394-0 libavcodec-dev libavcodec61
#   libavdevice61 libavfilter10 libavformat-dev libavformat61 libavutil-dev
#   libavutil59 libbs2b0 libcaca0 libcdio-cdda2t64 libcdio-paranoia2t64
#   libcdio19t64 libdavs2-16 libdecor-0-0 libdecor-0-plugin-1-gtk libdvdnav4
#   libdvdread8t64 libfdk-aac2 libfftw3-double3 libflac12t64 libflite1
#   libiec61883-0 libilbc3 libjack-jackd2-0 libkvazaar7 libldb2 liblilv-0-0
#   liblmdb0 libmysofa1 libopenal-data libopenal1 libopencore-amrnb0
#   libopencore-amrwb0 libopenh264-7 libplacebo338 libpostproc58 libpulse0
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libserd-0-0 libslang2
#   libsmbclient0 libsndfile1 libsndio7.0 libsord-0-0 libsratom-0-0
#   libswresample-dev libswresample5 libswscale-dev libswscale8 libtalloc2
#   libtdb1 libtevent0t64 libunibreak5 libvidstab1.1 libvmaf1 libvo-amrwbenc0
#   libvvenc1.12 libwbclient0 libxavs2-13 libxv1 libzimg2 libzix-0-0 samba-libs
# Suggested packages:
#   nvidia-vdpau-driver ffmpeg-doc alsa-utils libasound2-plugins
#   libnvidia-encode1 libdvdcss2 libfftw3-bin libfftw3-dev jackd2 libportaudio2
#   pulseaudio xdg-utils serdi sndiod sordi
# The following NEW packages will be installed:
#   alsa-topology-conf alsa-ucm-conf ffmpeg libaribb24-0t64 libasound2-data
#   libasound2t64 libass9 libasyncns0 libavc1394-0 libavcodec61 libavdevice61
#   libavfilter10 libavformat61 libavutil59 libbs2b0 libcaca0 libcdio-cdda2t64
#   libcdio-paranoia2t64 libcdio19t64 libdavs2-16 libdecor-0-0
#   libdecor-0-plugin-1-gtk libdvdnav4 libdvdread8t64 libfdk-aac2
#   libfftw3-double3 libflac12t64 libflite1 libiec61883-0 libilbc3
#   libjack-jackd2-0 libkvazaar7 libldb2 liblilv-0-0 liblmdb0 libmysofa1
#   libopenal-data libopenal1 libopencore-amrnb0 libopencore-amrwb0
#   libopenh264-7 libplacebo338 libpostproc58 libpulse0 librubberband2
#   libsamplerate0 libsdl2-2.0-0 libserd-0-0 libslang2 libsmbclient0 libsndfile1
#   libsndio7.0 libsord-0-0 libsratom-0-0 libswresample5 libswscale8 libtalloc2
#   libtdb1 libtevent0t64 libunibreak5 libvidstab1.1 libvmaf1 libvo-amrwbenc0
#   libvvenc1.12 libwbclient0 libxavs2-13 libxv1 libzimg2 libzix-0-0 samba-libs
# The following packages will be upgraded:
#   libavcodec-dev libavformat-dev libavutil-dev libswresample-dev
#   libswscale-dev
# 5 upgraded, 70 newly installed, 0 to remove and 86 not upgraded.
# Need to get 55.3 MB of archives.
# After this operation, 124 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu noble/main amd64 libslang2 amd64 2.3.3-3build2 [506 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavutil59 amd64 7:7.1.1-0build1~ubuntu2404 [367 kB]
# Get:3 http://archive.ubuntu.com/ubuntu noble/main amd64 liblmdb0 amd64 0.9.31-1build1 [48.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu noble/main amd64 alsa-topology-conf all 1.2.5.1-2 [15.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libasound2-data all 1.2.11-1ubuntu0.1 [21.1 kB]
# Get:6 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libasound2t64 amd64 1.2.11-1ubuntu0.1 [399 kB]
# Get:7 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 alsa-ucm-conf all 1.2.10-1ubuntu5.7 [66.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu noble/universe amd64 libaribb24-0t64 amd64 1.0.3-2.1build2 [31.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdavs2-16 amd64 1.6-1build1 [259 kB]
# Get:10 http://archive.ubuntu.com/ubuntu noble/universe amd64 libfdk-aac2 amd64 2.0.2-3~ubuntu4 [332 kB]
# Get:11 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopencore-amrnb0 amd64 0.1.6-1build1 [98.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopencore-amrwb0 amd64 0.1.6-1build1 [53.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopenh264-7 amd64 2.4.1+dfsg-1 [409 kB]
# Get:14 http://archive.ubuntu.com/ubuntu noble/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2build1 [76.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu noble/universe amd64 libxavs2-13 amd64 1.3-1 [546 kB]
# Get:16 http://archive.ubuntu.com/ubuntu noble/main amd64 libavc1394-0 amd64 0.5.4-5build3 [15.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu noble/universe amd64 libunibreak5 amd64 5.1-2build1 [25.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu noble/universe amd64 libass9 amd64 1:0.17.1-2build1 [104 kB]
# Get:19 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdvdread8t64 amd64 6.1.3-1.1build1 [54.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu noble/universe amd64 libdvdnav4 amd64 6.1.1-3build1 [39.5 kB]
# Get:21 http://archive.ubuntu.com/ubuntu noble/main amd64 libtalloc2 amd64 2.4.2-1build2 [27.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu noble/main amd64 libtdb1 amd64 1.4.10-1build1 [46.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu noble/main amd64 libtevent0t64 amd64 0.16.1-2build1 [42.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libldb2 amd64 2:2.8.0+samba4.19.5+dfsg-4ubuntu9.4 [188 kB]
# Get:25 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libwbclient0 amd64 2:4.19.5+dfsg-4ubuntu9.4 [71.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 samba-libs amd64 2:4.19.5+dfsg-4ubuntu9.4 [6018 kB]
# Get:27 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsmbclient0 amd64 2:4.19.5+dfsg-4ubuntu9.4 [62.4 kB]
# Get:28 http://archive.ubuntu.com/ubuntu noble/universe amd64 libbs2b0 amd64 3.1.0+dfsg-7build1 [10.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu noble/universe amd64 libflite1 amd64 2.2-6build3 [13.6 MB]
# Get:30 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libilbc3 amd64 3.0.4-0build1~noble [52.6 kB]
# Get:31 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libkvazaar7 amd64 2.2.0-0build1~noble [259 kB]
# Get:32 http://archive.ubuntu.com/ubuntu noble/universe amd64 libserd-0-0 amd64 0.32.2-1 [43.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu noble/universe amd64 libzix-0-0 amd64 0.4.2-2build1 [23.6 kB]
# Get:34 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsord-0-0 amd64 0.16.16-2build1 [15.8 kB]
# Get:35 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsratom-0-0 amd64 0.6.16-1build1 [17.3 kB]
# Get:36 http://archive.ubuntu.com/ubuntu noble/universe amd64 liblilv-0-0 amd64 0.24.22-1build1 [41.0 kB]
# Get:37 http://archive.ubuntu.com/ubuntu noble/universe amd64 libmysofa1 amd64 1.3.2+dfsg-2ubuntu2 [1158 kB]
# Get:38 http://archive.ubuntu.com/ubuntu noble/main amd64 libfftw3-double3 amd64 3.3.10-1ubuntu3 [838 kB]
# Get:39 http://archive.ubuntu.com/ubuntu noble/main amd64 libsamplerate0 amd64 0.2.2-4build1 [1344 kB]
# Get:40 http://archive.ubuntu.com/ubuntu noble/universe amd64 librubberband2 amd64 3.3.0+dfsg-2build1 [130 kB]
# Get:41 http://archive.ubuntu.com/ubuntu noble/universe amd64 libvidstab1.1 amd64 1.1.0-2build1 [38.5 kB]
# Get:42 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libswresample5 amd64 7:7.1.1-0build1~ubuntu2404 [74.6 kB]
# Get:43 http://archive.ubuntu.com/ubuntu noble/universe amd64 libzimg2 amd64 3.0.5+ds1-1build1 [254 kB]
# Get:44 http://archive.ubuntu.com/ubuntu noble/main amd64 libcaca0 amd64 0.99.beta20-4build2 [208 kB]
# Get:45 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libcdio19t64 amd64 2.1.0-4.1ubuntu1.2 [62.4 kB]
# Get:46 http://archive.ubuntu.com/ubuntu noble/main amd64 libcdio-cdda2t64 amd64 10.2+2.0.1-1.1build2 [16.5 kB]
# Get:47 http://archive.ubuntu.com/ubuntu noble/main amd64 libcdio-paranoia2t64 amd64 10.2+2.0.1-1.1build2 [16.6 kB]
# Get:48 http://archive.ubuntu.com/ubuntu noble/main amd64 libiec61883-0 amd64 1.2.0-6build1 [24.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu noble/main amd64 libjack-jackd2-0 amd64 1.9.21~dfsg-3ubuntu3 [289 kB]
# Get:50 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libvvenc1.12 amd64 1.12.0-0build5~ubuntu2404 [1219 kB]
# Get:51 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopenal-data all 1:1.23.1-4build1 [161 kB]
# Get:52 http://archive.ubuntu.com/ubuntu noble/universe amd64 libsndio7.0 amd64 1.9.0-0.3build3 [29.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu noble/universe amd64 libopenal1 amd64 1:1.23.1-4build1 [540 kB]
# Get:54 http://archive.ubuntu.com/ubuntu noble/main amd64 libasyncns0 amd64 0.8-6build4 [11.3 kB]
# Get:55 http://archive.ubuntu.com/ubuntu noble/main amd64 libflac12t64 amd64 1.4.3+ds-2.1ubuntu2 [197 kB]
# Get:56 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsndfile1 amd64 1.2.2-1ubuntu5.24.04.1 [209 kB]
# Get:57 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libpulse0 amd64 1:16.1+dfsg1-2ubuntu10.1 [292 kB]
# Get:58 http://archive.ubuntu.com/ubuntu noble/main amd64 libdecor-0-0 amd64 0.2.2-1build2 [16.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu noble-updates/main amd64 libsdl2-2.0-0 amd64 2.30.0+dfsg-1ubuntu3.1 [686 kB]
# Get:60 http://archive.ubuntu.com/ubuntu noble/main amd64 libxv1 amd64 2:1.0.11-1.1build1 [10.7 kB]
# Get:61 http://archive.ubuntu.com/ubuntu noble/universe amd64 libplacebo338 amd64 6.338.2-2build1 [2654 kB]
# Get:62 http://archive.ubuntu.com/ubuntu noble/main amd64 libdecor-0-plugin-1-gtk amd64 0.2.2-1build2 [22.2 kB]
# Get:63 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavcodec61 amd64 7:7.1.1-0build1~ubuntu2404 [6093 kB]
# Get:64 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavformat61 amd64 7:7.1.1-0build1~ubuntu2404 [1227 kB]
# Get:65 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libpostproc58 amd64 7:7.1.1-0build1~ubuntu2404 [61.5 kB]
# Get:66 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libswscale8 amd64 7:7.1.1-0build1~ubuntu2404 [218 kB]
# Get:67 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libvmaf1 amd64 2.3.1-0build2~noble [170 kB]
# Get:68 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavfilter10 amd64 7:7.1.1-0build1~ubuntu2404 [1784 kB]
# Get:69 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavdevice61 amd64 7:7.1.1-0build1~ubuntu2404 [94.1 kB]
# Get:70 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 ffmpeg amd64 7:7.1.1-0build1~ubuntu2404 [1984 kB]
# Get:71 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libswscale-dev amd64 7:7.1.1-0build1~ubuntu2404 [253 kB]
# Get:72 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavformat-dev amd64 7:7.1.1-0build1~ubuntu2404 [1483 kB]
# Get:73 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavcodec-dev amd64 7:7.1.1-0build1~ubuntu2404 [6805 kB]
# Get:74 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libswresample-dev amd64 7:7.1.1-0build1~ubuntu2404 [92.1 kB]
# Get:75 https://ppa.launchpadcontent.net/ubuntuhandbook1/ffmpeg7/ubuntu noble/main amd64 libavutil-dev amd64 7:7.1.1-0build1~ubuntu2404 [530 kB]
# Fetched 55.3 MB in 33s (1692 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libslang2:amd64.
# (Reading database ... 98342 files and directories currently installed.)
# Preparing to unpack .../00-libslang2_2.3.3-3build2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libslang2:amd64 (2.3.3-3build2) ...
# Selecting previously unselected package liblmdb0:amd64.
# Preparing to unpack .../01-liblmdb0_0.9.31-1build1_amd64.deb ...
# Unpacking liblmdb0:amd64 (0.9.31-1build1) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package alsa-topology-conf.
# Preparing to unpack .../02-alsa-topology-conf_1.2.5.1-2_all.deb ...
# Unpacking alsa-topology-conf (1.2.5.1-2) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../03-libasound2-data_1.2.11-1ubuntu0.1_all.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libasound2-data (1.2.11-1ubuntu0.1) ...
# Selecting previously unselected package libasound2t64:amd64.
# Preparing to unpack .../04-libasound2t64_1.2.11-1ubuntu0.1_amd64.deb ...
# Unpacking libasound2t64:amd64 (1.2.11-1ubuntu0.1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package alsa-ucm-conf.
# Preparing to unpack .../05-alsa-ucm-conf_1.2.10-1ubuntu5.7_all.deb ...
# Unpacking alsa-ucm-conf (1.2.10-1ubuntu5.7) ...
# Selecting previously unselected package libaribb24-0t64:amd64.
# Preparing to unpack .../06-libaribb24-0t64_1.0.3-2.1build2_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libaribb24-0t64:amd64 (1.0.3-2.1build2) ...
# Selecting previously unselected package libavutil59:amd64.
# Preparing to unpack .../07-libavutil59_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavutil59:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [  5%] [###.......................................................] 8Selecting previously unselected package libdavs2-16:amd64.
# Preparing to unpack .../08-libdavs2-16_1.6-1build1_amd64.deb ...
# Unpacking libdavs2-16:amd64 (1.6-1build1) ...
# Selecting previously unselected package libfdk-aac2:amd64.
# Preparing to unpack .../09-libfdk-aac2_2.0.2-3~ubuntu4_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libfdk-aac2:amd64 (2.0.2-3~ubuntu4) ...
# Selecting previously unselected package libilbc3:amd64.
# Preparing to unpack .../10-libilbc3_3.0.4-0build1~noble_amd64.deb ...
# Unpacking libilbc3:amd64 (3.0.4-0build1~noble) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libkvazaar7:amd64.
# Preparing to unpack .../11-libkvazaar7_2.2.0-0build1~noble_amd64.deb ...
# Unpacking libkvazaar7:amd64 (2.2.0-0build1~noble) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../12-libopencore-amrnb0_0.1.6-1build1_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libopencore-amrnb0:amd64 (0.1.6-1build1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../13-libopencore-amrwb0_0.1.6-1build1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.6-1build1) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package libopenh264-7:amd64.
# Preparing to unpack .../14-libopenh264-7_2.4.1+dfsg-1_amd64.deb ...
# Unpacking libopenh264-7:amd64 (2.4.1+dfsg-1) ...
# Selecting previously unselected package libswresample5:amd64.
# Preparing to unpack .../15-libswresample5_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libswresample5:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../16-libvo-amrwbenc0_0.1.3-2build1_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2build1) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libvvenc1.12:amd64.
# Preparing to unpack .../17-libvvenc1.12_1.12.0-0build5~ubuntu2404_amd64.deb ...
# Unpacking libvvenc1.12:amd64 (1.12.0-0build5~ubuntu2404) ...
# Selecting previously unselected package libxavs2-13:amd64.
# Preparing to unpack .../18-libxavs2-13_1.3-1_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libxavs2-13:amd64 (1.3-1) ...
# Selecting previously unselected package libavcodec61:amd64.
# Preparing to unpack .../19-libavcodec61_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavcodec61:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../20-libavc1394-0_0.5.4-5build3_amd64.deb ...
# Unpacking libavc1394-0:amd64 (0.5.4-5build3) ...
# Selecting previously unselected package libunibreak5:amd64.
# Preparing to unpack .../21-libunibreak5_5.1-2build1_amd64.deb ...
# 7Progress: [ 14%] [########..................................................] 8Unpacking libunibreak5:amd64 (5.1-2build1) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../22-libass9_1%3a0.17.1-2build1_amd64.deb ...
# Unpacking libass9:amd64 (1:0.17.1-2build1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libdvdread8t64:amd64.
# Preparing to unpack .../23-libdvdread8t64_6.1.3-1.1build1_amd64.deb ...
# Unpacking libdvdread8t64:amd64 (6.1.3-1.1build1) ...
# Selecting previously unselected package libdvdnav4:amd64.
# Preparing to unpack .../24-libdvdnav4_6.1.1-3build1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking libdvdnav4:amd64 (6.1.1-3build1) ...
# Selecting previously unselected package libtalloc2:amd64.
# Preparing to unpack .../25-libtalloc2_2.4.2-1build2_amd64.deb ...
# Unpacking libtalloc2:amd64 (2.4.2-1build2) ...
# 7Progress: [ 17%] [##########................................................] 8Selecting previously unselected package libtdb1:amd64.
# Preparing to unpack .../26-libtdb1_1.4.10-1build1_amd64.deb ...
# Unpacking libtdb1:amd64 (1.4.10-1build1) ...
# Selecting previously unselected package libtevent0t64:amd64.
# Preparing to unpack .../27-libtevent0t64_0.16.1-2build1_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libtevent0t64:amd64 (0.16.1-2build1) ...
# Selecting previously unselected package libldb2:amd64.
# Preparing to unpack .../28-libldb2_2%3a2.8.0+samba4.19.5+dfsg-4ubuntu9.4_amd64.deb ...
# Unpacking libldb2:amd64 (2:2.8.0+samba4.19.5+dfsg-4ubuntu9.4) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libwbclient0:amd64.
# Preparing to unpack .../29-libwbclient0_2%3a4.19.5+dfsg-4ubuntu9.4_amd64.deb ...
# Unpacking libwbclient0:amd64 (2:4.19.5+dfsg-4ubuntu9.4) ...
# Selecting previously unselected package samba-libs:amd64.
# Preparing to unpack .../30-samba-libs_2%3a4.19.5+dfsg-4ubuntu9.4_amd64.deb ...
# 7Progress: [ 20%] [###########...............................................] 8Unpacking samba-libs:amd64 (2:4.19.5+dfsg-4ubuntu9.4) ...
# Selecting previously unselected package libsmbclient0:amd64.
# Preparing to unpack .../31-libsmbclient0_2%3a4.19.5+dfsg-4ubuntu9.4_amd64.deb ...
# Unpacking libsmbclient0:amd64 (2:4.19.5+dfsg-4ubuntu9.4) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libavformat61:amd64.
# Preparing to unpack .../32-libavformat61_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavformat61:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../33-libbs2b0_3.1.0+dfsg-7build1_amd64.deb ...
# 7Progress: [ 22%] [############..............................................] 8Unpacking libbs2b0:amd64 (3.1.0+dfsg-7build1) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../34-libflite1_2.2-6build3_amd64.deb ...
# Unpacking libflite1:amd64 (2.2-6build3) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../35-libserd-0-0_0.32.2-1_amd64.deb ...
# Unpacking libserd-0-0:amd64 (0.32.2-1) ...
# Selecting previously unselected package libzix-0-0:amd64.
# Preparing to unpack .../36-libzix-0-0_0.4.2-2build1_amd64.deb ...
# 7Progress: [ 24%] [##############............................................] 8Unpacking libzix-0-0:amd64 (0.4.2-2build1) ...
# Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../37-libsord-0-0_0.16.16-2build1_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.16-2build1) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../38-libsratom-0-0_0.6.16-1build1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.16-1build1) ...
# Selecting previously unselected package liblilv-0-0:amd64.
# Preparing to unpack .../39-liblilv-0-0_0.24.22-1build1_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking liblilv-0-0:amd64 (0.24.22-1build1) ...
# Selecting previously unselected package libmysofa1:amd64.
# Preparing to unpack .../40-libmysofa1_1.3.2+dfsg-2ubuntu2_amd64.deb ...
# Unpacking libmysofa1:amd64 (1.3.2+dfsg-2ubuntu2) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libpostproc58:amd64.
# Preparing to unpack .../41-libpostproc58_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libpostproc58:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../42-libfftw3-double3_3.3.10-1ubuntu3_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libfftw3-double3:amd64 (3.3.10-1ubuntu3) ...
# Selecting previously unselected package libsamplerate0:amd64.
# Preparing to unpack .../43-libsamplerate0_0.2.2-4build1_amd64.deb ...
# Unpacking libsamplerate0:amd64 (0.2.2-4build1) ...
# 7Progress: [ 29%] [################..........................................] 8Selecting previously unselected package librubberband2:amd64.
# Preparing to unpack .../44-librubberband2_3.3.0+dfsg-2build1_amd64.deb ...
# Unpacking librubberband2:amd64 (3.3.0+dfsg-2build1) ...
# Selecting previously unselected package libswscale8:amd64.
# Preparing to unpack .../45-libswscale8_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libswscale8:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Selecting previously unselected package libvidstab1.1:amd64.
# Preparing to unpack .../46-libvidstab1.1_1.1.0-2build1_amd64.deb ...
# Unpacking libvidstab1.1:amd64 (1.1.0-2build1) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libvmaf1:amd64.
# Preparing to unpack .../47-libvmaf1_2.3.1-0build2~noble_amd64.deb ...
# Unpacking libvmaf1:amd64 (2.3.1-0build2~noble) ...
# Selecting previously unselected package libzimg2:amd64.
# Preparing to unpack .../48-libzimg2_3.0.5+ds1-1build1_amd64.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking libzimg2:amd64 (3.0.5+ds1-1build1) ...
# Selecting previously unselected package libavfilter10:amd64.
# Preparing to unpack .../49-libavfilter10_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavfilter10:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libcaca0:amd64.
# Preparing to unpack .../50-libcaca0_0.99.beta20-4build2_amd64.deb ...
# Unpacking libcaca0:amd64 (0.99.beta20-4build2) ...
# Selecting previously unselected package libcdio19t64:amd64.
# Preparing to unpack .../51-libcdio19t64_2.1.0-4.1ubuntu1.2_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libcdio19t64:amd64 (2.1.0-4.1ubuntu1.2) ...
# Selecting previously unselected package libcdio-cdda2t64:amd64.
# Preparing to unpack .../52-libcdio-cdda2t64_10.2+2.0.1-1.1build2_amd64.deb ...
# Unpacking libcdio-cdda2t64:amd64 (10.2+2.0.1-1.1build2) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libcdio-paranoia2t64:amd64.
# Preparing to unpack .../53-libcdio-paranoia2t64_10.2+2.0.1-1.1build2_amd64.deb ...
# Unpacking libcdio-paranoia2t64:amd64 (10.2+2.0.1-1.1build2) ...
# Selecting previously unselected package libiec61883-0:amd64.
# Preparing to unpack .../54-libiec61883-0_1.2.0-6build1_amd64.deb ...
# 7Progress: [ 36%] [#####################.....................................] 8Unpacking libiec61883-0:amd64 (1.2.0-6build1) ...
# Selecting previously unselected package libjack-jackd2-0:amd64.
# Preparing to unpack .../55-libjack-jackd2-0_1.9.21~dfsg-3ubuntu3_amd64.deb ...
# Unpacking libjack-jackd2-0:amd64 (1.9.21~dfsg-3ubuntu3) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libopenal-data.
# Preparing to unpack .../56-libopenal-data_1%3a1.23.1-4build1_all.deb ...
# Unpacking libopenal-data (1:1.23.1-4build1) ...
# Selecting previously unselected package libsndio7.0:amd64.
# Preparing to unpack .../57-libsndio7.0_1.9.0-0.3build3_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libsndio7.0:amd64 (1.9.0-0.3build3) ...
# Selecting previously unselected package libopenal1:amd64.
# Preparing to unpack .../58-libopenal1_1%3a1.23.1-4build1_amd64.deb ...
# Unpacking libopenal1:amd64 (1:1.23.1-4build1) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package libasyncns0:amd64.
# Preparing to unpack .../59-libasyncns0_0.8-6build4_amd64.deb ...
# Unpacking libasyncns0:amd64 (0.8-6build4) ...
# Selecting previously unselected package libflac12t64:amd64.
# Preparing to unpack .../60-libflac12t64_1.4.3+ds-2.1ubuntu2_amd64.deb ...
# 7Progress: [ 40%] [#######################...................................] 8Unpacking libflac12t64:amd64 (1.4.3+ds-2.1ubuntu2) ...
# Selecting previously unselected package libsndfile1:amd64.
# Preparing to unpack .../61-libsndfile1_1.2.2-1ubuntu5.24.04.1_amd64.deb ...
# Unpacking libsndfile1:amd64 (1.2.2-1ubuntu5.24.04.1) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package libpulse0:amd64.
# Preparing to unpack .../62-libpulse0_1%3a16.1+dfsg1-2ubuntu10.1_amd64.deb ...
# Unpacking libpulse0:amd64 (1:16.1+dfsg1-2ubuntu10.1) ...
# Selecting previously unselected package libdecor-0-0:amd64.
# Preparing to unpack .../63-libdecor-0-0_0.2.2-1build2_amd64.deb ...
# 7Progress: [ 42%] [########################..................................] 8Unpacking libdecor-0-0:amd64 (0.2.2-1build2) ...
# Selecting previously unselected package libsdl2-2.0-0:amd64.
# Preparing to unpack .../64-libsdl2-2.0-0_2.30.0+dfsg-1ubuntu3.1_amd64.deb ...
# Unpacking libsdl2-2.0-0:amd64 (2.30.0+dfsg-1ubuntu3.1) ...
# 7Progress: [ 43%] [#########################.................................] 8Selecting previously unselected package libxv1:amd64.
# Preparing to unpack .../65-libxv1_2%3a1.0.11-1.1build1_amd64.deb ...
# Unpacking libxv1:amd64 (2:1.0.11-1.1build1) ...
# Selecting previously unselected package libavdevice61:amd64.
# Preparing to unpack .../66-libavdevice61_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# 7Progress: [ 44%] [#########################.................................] 8Unpacking libavdevice61:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Selecting previously unselected package libplacebo338:amd64.
# Preparing to unpack .../67-libplacebo338_6.338.2-2build1_amd64.deb ...
# Unpacking libplacebo338:amd64 (6.338.2-2build1) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package ffmpeg.
# Preparing to unpack .../68-ffmpeg_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking ffmpeg (7:7.1.1-0build1~ubuntu2404) ...
# Preparing to unpack .../69-libswscale-dev_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# 7Progress: [ 46%] [##########################................................] 8Unpacking libswscale-dev:amd64 (7:7.1.1-0build1~ubuntu2404) over (7:6.1.1-3ubuntu5) ...
# Preparing to unpack .../70-libavformat-dev_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavformat-dev:amd64 (7:7.1.1-0build1~ubuntu2404) over (7:6.1.1-3ubuntu5) ...
# 7Progress: [ 47%] [###########################...............................] 8Preparing to unpack .../71-libavcodec-dev_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavcodec-dev:amd64 (7:7.1.1-0build1~ubuntu2404) over (7:6.1.1-3ubuntu5) ...
# Preparing to unpack .../72-libswresample-dev_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# 7Progress: [ 48%] [###########################...............................] 8Unpacking libswresample-dev:amd64 (7:7.1.1-0build1~ubuntu2404) over (7:6.1.1-3ubuntu5) ...
# Preparing to unpack .../73-libavutil-dev_7%3a7.1.1-0build1~ubuntu2404_amd64.deb ...
# Unpacking libavutil-dev:amd64 (7:7.1.1-0build1~ubuntu2404) over (7:6.1.1-3ubuntu5) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package libdecor-0-plugin-1-gtk:amd64.
# Preparing to unpack .../74-libdecor-0-plugin-1-gtk_0.2.2-1build2_amd64.deb ...
# Unpacking libdecor-0-plugin-1-gtk:amd64 (0.2.2-1build2) ...
# Setting up libavc1394-0:amd64 (0.5.4-5build3) ...
# 7Progress: [ 50%] [#############################.............................] 8Setting up liblmdb0:amd64 (0.9.31-1build1) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libfdk-aac2:amd64 (2.0.2-3~ubuntu4) ...
# Setting up libdvdread8t64:amd64 (6.1.3-1.1build1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libvo-amrwbenc0:amd64 (0.1.3-2build1) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up libvmaf1:amd64 (2.3.1-0build2~noble) ...
# Setting up libzix-0-0:amd64 (0.4.2-2build1) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libtdb1:amd64 (1.4.10-1build1) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libaribb24-0t64:amd64 (1.0.3-2.1build2) ...
# Setting up libmysofa1:amd64 (1.3.2+dfsg-2ubuntu2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libcdio19t64:amd64 (2.1.0-4.1ubuntu1.2) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libilbc3:amd64 (3.0.4-0build1~noble) ...
# Setting up libavutil59:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libwbclient0:amd64 (2:4.19.5+dfsg-4ubuntu9.4) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libcdio-cdda2t64:amd64 (10.2+2.0.1-1.1build2) ...
# Setting up libpostproc58:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libtalloc2:amd64 (2.4.2-1build2) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libasound2-data (1.2.11-1ubuntu0.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.6-1build1) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libswresample5:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libswscale8:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Setting up libplacebo338:amd64 (6.338.2-2build1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libasound2t64:amd64 (1.2.11-1ubuntu0.1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libslang2:amd64 (2.3.3-3build2) ...
# Setting up libcdio-paranoia2t64:amd64 (10.2+2.0.1-1.1build2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up libxv1:amd64 (2:1.0.11-1.1build1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up libunibreak5:amd64 (5.1-2build1) ...
# Setting up libfftw3-double3:amd64 (3.3.10-1ubuntu3) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libopenh264-7:amd64 (2.4.1+dfsg-1) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libsndio7.0:amd64 (1.9.0-0.3build3) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2build1) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up alsa-topology-conf (1.2.5.1-2) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libflite1:amd64 (2.2-6build3) ...
# Setting up libxavs2-13:amd64 (1.3-1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libasyncns0:amd64 (0.8-6build4) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libbs2b0:amd64 (3.1.0+dfsg-7build1) ...
# Setting up libdavs2-16:amd64 (1.6-1build1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libopencore-amrnb0:amd64 (0.1.6-1build1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libdecor-0-0:amd64 (0.2.2-1build2) ...
# Setting up libzimg2:amd64 (3.0.5+ds1-1build1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libopenal-data (1:1.23.1-4build1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libflac12t64:amd64 (1.4.3+ds-2.1ubuntu2) ...
# Setting up libsndfile1:amd64 (1.2.2-1ubuntu5.24.04.1) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libvvenc1.12:amd64 (1.12.0-0build5~ubuntu2404) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libsamplerate0:amd64 (0.2.2-4build1) ...
# Setting up libdecor-0-plugin-1-gtk:amd64 (0.2.2-1build2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libtevent0t64:amd64 (0.16.1-2build1) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libdvdnav4:amd64 (6.1.1-3build1) ...
# Setting up libiec61883-0:amd64 (1.2.0-6build1) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libserd-0-0:amd64 (0.32.2-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libkvazaar7:amd64 (2.2.0-0build1~noble) ...
# Setting up libavutil-dev:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libcaca0:amd64 (0.99.beta20-4build2) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up alsa-ucm-conf (1.2.10-1ubuntu5.7) ...
# Setting up libpulse0:amd64 (1:16.1+dfsg1-2ubuntu10.1) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libswresample-dev:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libopenal1:amd64 (1:1.23.1-4build1) ...
# Setting up libass9:amd64 (1:0.17.1-2build1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libswscale-dev:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libavcodec61:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Setting up librubberband2:amd64 (3.3.0+dfsg-2build1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libjack-jackd2-0:amd64 (1.9.21~dfsg-3ubuntu3) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libsord-0-0:amd64 (0.16.16-2build1) ...
# Setting up libsratom-0-0:amd64 (0.6.16-1build1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libsdl2-2.0-0:amd64 (2.30.0+dfsg-1ubuntu3.1) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libldb2:amd64 (2:2.8.0+samba4.19.5+dfsg-4ubuntu9.4) ...
# Setting up liblilv-0-0:amd64 (0.24.22-1build1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libavcodec-dev:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up samba-libs:amd64 (2:4.19.5+dfsg-4ubuntu9.4) ...
# Setting up libsmbclient0:amd64 (2:4.19.5+dfsg-4ubuntu9.4) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libavformat61:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libavfilter10:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# Setting up libavdevice61:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libavformat-dev:amd64 (7:7.1.1-0build1~ubuntu2404) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up ffmpeg (7:7.1.1-0build1~ubuntu2404) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.5) ...
#
# 78

# %% [markdown]
# ## Install LeRobot v0.4.1
# This cell clones the `lerobot` repository from Hugging Face, and installs the package in editable mode. Extra Features: To install additional dependencies for training SmolVLA or Pi models, refer to the [LeRobot offical page](https://huggingface.co/docs/lerobot/index).

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !cd lerobot && git checkout -b v0.4.2 v0.4.2 # let’s synchronize using this version
# !cd lerobot && pip install -e .
# Out:
# Cloning into 'lerobot'...
# remote: Enumerating objects: 44252, done.
# remote: Counting objects: 100% (281/281), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 44252 (delta 214), reused 113 (delta 105), pack-reused 43971 (from 4)
# Receiving objects: 100% (44252/44252), 220.73 MiB | 74.92 MiB/s, done.
# Resolving deltas: 100% (28517/28517), done.
# Switched to a new branch 'v0.4.2'
# Obtaining file:///workspace/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting datasets<4.2.0,>=4.0.0 (from lerobot==0.4.2)
#   Downloading datasets-4.1.1-py3-none-any.whl.metadata (18 kB)
# Collecting diffusers<0.36.0,>=0.27.2 (from lerobot==0.4.2)
#   Downloading diffusers-0.35.2-py3-none-any.whl.metadata (20 kB)
# Collecting huggingface-hub<0.36.0,>=0.34.2 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting accelerate<2.0.0,>=1.10.0 (from lerobot==0.4.2)
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.2) (80.9.0)
# Collecting cmake<4.2.0,>=3.29.0.1 (from lerobot==0.4.2)
#   Downloading cmake-4.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.5 kB)
# Collecting einops<0.9.0,>=0.8.0 (from lerobot==0.4.2)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting opencv-python-headless<4.13.0,>=4.9.0 (from lerobot==0.4.2)
#   Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting av<16.0.0,>=15.0.0 (from lerobot==0.4.2)
#   Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting jsonlines<5.0.0,>=4.0.0 (from lerobot==0.4.2)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<26.0,>=24.2 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.2) (25.0)
# Collecting pynput<1.9.0,>=1.7.7 (from lerobot==0.4.2)
#   Downloading pynput-1.8.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting pyserial<4.0,>=3.5 (from lerobot==0.4.2)
#   Downloading pyserial-3.5-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting wandb<0.22.0,>=0.20.0 (from lerobot==0.4.2)
#   Downloading wandb-0.21.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<2.8.0,>=2.2.1 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.2) (2.7.1+rocm7.0.0.lw.git698b58a9)
# Collecting torchcodec<0.6.0,>=0.2.1 (from lerobot==0.4.2)
#   Downloading torchcodec-0.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torchvision<0.23.0,>=0.21.0 in /opt/venv/lib/python3.12/site-packages (from lerobot==0.4.2) (0.22.1+rocm7.0.0.git59a3e1f9)
# Collecting draccus==0.10.0 (from lerobot==0.4.2)
#   Downloading draccus-0.10.0-py3-none-any.whl.metadata (24 kB)
# Collecting gymnasium<2.0.0,>=1.1.1 (from lerobot==0.4.2)
#   Downloading gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting rerun-sdk<0.27.0,>=0.24.0 (from lerobot==0.4.2)
#   Downloading rerun_sdk-0.26.2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting deepdiff<9.0.0,>=7.0.1 (from lerobot==0.4.2)
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Collecting imageio<3.0.0,>=2.34.0 (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.2)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting termcolor<4.0.0,>=2.4.0 (from lerobot==0.4.2)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting mergedeep~=1.3 (from draccus==0.10.0->lerobot==0.4.2)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyyaml~=6.0 in /opt/venv/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.4.2) (6.0.2)
# Collecting pyyaml-include~=1.4 (from draccus==0.10.0->lerobot==0.4.2)
#   Downloading pyyaml_include-1.4.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting toml~=0.10 (from draccus==0.10.0->lerobot==0.4.2)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect~=0.9.0 (from draccus==0.10.0->lerobot==0.4.2)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.2) (2.3.3)
# Requirement already satisfied: psutil in /opt/venv/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.2) (7.1.3)
# Collecting safetensors>=0.4.3 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.2)
#   Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: filelock in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (3.19.1)
# Collecting pyarrow>=21.0.0 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/venv/lib/python3.12/site-packages (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (4.67.1)
# Collecting xxhash (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /opt/venv/lib/python3.12/site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2025.9.0)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0.0,>=7.0.1->lerobot==0.4.2)
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting importlib_metadata (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.2)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting regex!=2019.12.17 (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.2)
#   Downloading regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: Pillow in /opt/venv/lib/python3.12/site-packages (from diffusers<0.36.0,>=0.27.2->lerobot==0.4.2) (11.3.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading aiohttp-3.13.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.2)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/venv/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.2) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<2.0.0,>=1.1.1->lerobot==0.4.2)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<0.36.0,>=0.34.2->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2)
#   Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting InquirerPy==0.3.4 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2)
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting hf-transfer>=0.1.4 (from huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2)
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /opt/venv/lib/python3.12/site-packages (from InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2) (3.0.52)
# Collecting imageio-ffmpeg (from imageio[ffmpeg]<3.0.0,>=2.34.0->lerobot==0.4.2)
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/venv/lib/python3.12/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot==0.4.2) (25.4.0)
# Collecting numpy>=1.17 (from accelerate<2.0.0,>=1.10.0->lerobot==0.4.2)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: wcwidth in /opt/venv/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface-hub[cli,hf-transfer]<0.36.0,>=0.34.2->lerobot==0.4.2) (0.2.14)
# Requirement already satisfied: six in /opt/venv/lib/python3.12/site-packages (from pynput<1.9.0,>=1.7.7->lerobot==0.4.2) (1.17.0)
# Collecting evdev>=1.3 (from pynput<1.9.0,>=1.7.7->lerobot==0.4.2)
#   Downloading evdev-1.9.2.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-xlib>=0.17 (from pynput<1.9.0,>=1.7.7->lerobot==0.4.2)
#   Downloading python_xlib-0.33-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: sympy>=1.13.3 in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.2) (1.14.0)
# Requirement already satisfied: networkx in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.2) (3.5)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.2) (3.1.6)
# Requirement already satisfied: pytorch-triton-rocm==3.3.1+rocm7.0.0.git9c7bc0a3 in /opt/venv/lib/python3.12/site-packages (from torch<2.8.0,>=2.2.1->lerobot==0.4.2) (3.3.1+rocm7.0.0.git9c7bc0a3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.4.2)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting click>=8.0.1 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /opt/venv/lib/python3.12/site-packages (from wandb<0.22.0,>=0.20.0->lerobot==0.4.2) (4.5.0)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sentry-sdk>=2.0.0 (from wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading sentry_sdk-2.47.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3->wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2025.11.12)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets<4.2.0,>=4.0.0->lerobot==0.4.2)
#   Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.22.0,>=0.20.0->lerobot==0.4.2)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.8.0,>=2.2.1->lerobot==0.4.2) (1.3.0)
# Collecting zipp>=3.20 (from importlib_metadata->diffusers<0.36.0,>=0.27.2->lerobot==0.4.2)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.12/site-packages (from jinja2->torch<2.8.0,>=2.2.1->lerobot==0.4.2) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/venv/lib/python3.12/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.12/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/venv/lib/python3.12/site-packages (from pandas->datasets<4.2.0,>=4.0.0->lerobot==0.4.2) (2025.2)
# Downloading draccus-0.10.0-py3-none-any.whl (71 kB)
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Downloading av-15.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 119.2 MB/s  0:00:00 eta 0:00:01
# Downloading cmake-4.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 128.1 MB/s  0:00:00m0:00:01
# Downloading datasets-4.1.1-py3-none-any.whl (503 kB)
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
# Downloading diffusers-0.35.2-py3-none-any.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 133.8 MB/s  0:00:00
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading gymnasium-1.2.2-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 139.4 MB/s  0:00:00
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 85.3 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 116.6 MB/s  0:00:00
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading opencv_python_headless-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (54.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 MB 96.3 MB/s  0:00:00 eta 0:00:01
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 130.7 MB/s  0:00:00
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Downloading pynput-1.8.1-py2.py3-none-any.whl (91 kB)
# Downloading pyserial-3.5-py2.py3-none-any.whl (90 kB)
# Downloading pyyaml_include-1.4.1-py3-none-any.whl (19 kB)
# Downloading rerun_sdk-0.26.2-cp39-abi3-manylinux_2_28_x86_64.whl (98.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 MB 131.9 MB/s  0:00:00 eta 0:00:01
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading torchcodec-0.5-cp312-cp312-manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 161.2 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading wandb-0.21.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 33.2 MB/s  0:00:00 eta 0:00:01
# Downloading protobuf-6.33.1-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 188.1 MB/s  0:00:00
# Downloading aiohttp-3.13.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 96.5 MB/s  0:00:00
# Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 122.5 MB/s  0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 133.1 MB/s  0:00:00 eta 0:00:01
# Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
# Downloading regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 136.3 MB/s  0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Downloading sentry_sdk-2.47.0-py2.py3-none-any.whl (411 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 133.3 MB/s  0:00:00m0:00:01
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading xxhash-3.6.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Building wheels for collected packages: lerobot, evdev
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.4.2-0.editable-py3-none-any.whl size=15632 sha256=ded403827952359ef55ae1d4c3ee396d724361c37c7b80881f2990c0b0fb857b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pwu81wxw/wheels/05/0a/0d/80a4c08845345c44fe1e5f70929884983b90d85f46a77f7601
#   Building wheel for evdev (pyproject.toml) ... done
#   Created wheel for evdev: filename=evdev-1.9.2-cp312-cp312-linux_x86_64.whl size=114623 sha256=6d5d654230ed4f06e58bb85a4012f0acd5bec541b487b8caa73d1e542308c02f
#   Stored in directory: /root/.cache/pip/wheels/19/f7/62/6b6f5201f6536a3a9e38c94726e03a3b2bded0aaf7782b12d7
# Successfully built lerobot evdev
# Installing collected packages: pyserial, farama-notifications, zipp, xxhash, typing-inspection, torchcodec, toml, termcolor, smmap, sentry-sdk, safetensors, regex, pyyaml-include, python-xlib, pydantic-core, pyarrow, protobuf, propcache, pfzy, orderly-set, numpy, mypy-extensions, multidict, mergedeep, jsonlines, imageio-ffmpeg, hf-xet, hf-transfer, frozenlist, evdev, einops, dill, cmake, cloudpickle, click, av, annotated-types, aiohappyeyeballs, yarl, typing-inspect, rerun-sdk, pynput, pydantic, opencv-python-headless, multiprocess, InquirerPy, importlib_metadata, imageio, huggingface-hub, gymnasium, gitdb, deepdiff, aiosignal, gitpython, draccus, diffusers, aiohttp, accelerate, wandb, datasets, lerobot
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/61 [protobuf]core]
#     Found existing installation: numpy 2.3.3━━━━━━━━━━━━━━━━━━ 16/61 [protobuf]
#     Uninstalling numpy-2.3.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/61 [protobuf]
#       Successfully uninstalled numpy-2.3.3━━━━━━━━━━━━━━━━━━━━━━━━ 20/61 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61/61 [lerobot]9/61 [datasets]e]-hub]adless]
# Successfully installed InquirerPy-0.3.4 accelerate-1.12.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 av-15.1.0 click-8.3.1 cloudpickle-3.1.2 cmake-4.1.3 datasets-4.1.1 deepdiff-8.6.1 diffusers-0.35.2 dill-0.4.0 draccus-0.10.0 einops-0.8.1 evdev-1.9.2 farama-notifications-0.0.4 frozenlist-1.8.0 gitdb-4.0.12 gitpython-3.1.45 gymnasium-1.2.2 hf-transfer-0.1.9 hf-xet-1.2.0 huggingface-hub-0.35.3 imageio-2.37.2 imageio-ffmpeg-0.6.0 importlib_metadata-8.7.0 jsonlines-4.0.0 lerobot-0.4.2 mergedeep-1.3.4 multidict-6.7.0 multiprocess-0.70.16 mypy-extensions-1.1.0 numpy-2.2.6 opencv-python-headless-4.12.0.88 orderly-set-5.5.0 pfzy-0.3.4 propcache-0.4.1 protobuf-6.33.1 pyarrow-22.0.0 pydantic-2.12.5 pydantic-core-2.41.5 pynput-1.8.1 pyserial-3.5 python-xlib-0.33 pyyaml-include-1.4.1 regex-2025.11.3 rerun-sdk-0.26.2 safetensors-0.7.0 sentry-sdk-2.47.0 smmap-5.0.2 termcolor-3.2.0 toml-0.10.2 torchcodec-0.5 typing-inspect-0.9.0 typing-inspection-0.4.2 wandb-0.21.4 xxhash-3.6.0 yarl-1.22.0 zipp-3.23.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Weights & Biases login
# This cell install and log into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !pip install wandb
import wandb
wandb.login(key="")

# %% [markdown]
# ## Login into Hugging Face Hub

# %%
from huggingface_hub import login
login(token="")

# %% [markdown]
# ## Start Training Models with LeRobot
#
# This cell uses the lerobot-train CLI from the lerobot library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `lerobot/svla_so100_pickplace`.
#
# 2. `--policy.type=act`:
#    Specifies the policy configuration to use. `act` refers to [configuration_act.py](../lerobot/common/policies/act/configuration_act.py), which will automatically adapt to your dataset’s setup (e.g., number of motors and cameras).
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.The name typically includes the model type (e.g., act, smolvla), the dataset name, and additional descriptive tags.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an AMD or NVIDIA GPU.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.
#
# 7. `--policy.push_to_hub=`:
#
#    Enables automatic uploading of the trained policy to the Hugging Face Hub. You must specify `--policy.repo_id` (e.g., ${HF_USER}/{REPO_NAME}) if it is True.

# %%
# !lerobot-train \
  --dataset.repo_id=masato-ka/greate-akihabara-take2-misson1 \
  --batch_size=8 \
  --save_freq=5000 \
  --steps=20000 \
  --output_dir=outputs/train/act_greate_akihabara_misson1 \
  --job_name=greate_akihabara_misson1 \
  --policy.device=cuda \
  --policy.type=act \
  --policy.push_to_hub=true \
  --policy.repo_id=masato-ka/act-greate-akihabara-take2-misson1 \
  --wandb.enable=true
# Out:
# INFO 2025-12-05 14:16:55 ot_train.py:163 {'batch_size': 8,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'masato-ka/greate-akihabara-take2-misson1',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'greate_akihabara_misson1',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_greate_akihabara_misson1',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': True,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': 'masato-ka/act-greate-akihabara-take2-misson1',
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 5000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 20000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /opt/venv/lib/python3.12/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO 2025-12-05 14:16:56 db_utils.py:102 Logs will be synced with wandb.
# INFO 2025-12-05 14:16:56 db_utils.py:103 Track this run --> https://wandb.ai/masato-ka-personal/lerobot/runs/rzo5s3aa
# INFO 2025-12-05 14:16:56 ot_train.py:183 Creating dataset
# Fetching 5 files:   0%|                                   | 0/5 [00:00<?, ?it/s]
# meta/episodes/chunk-000/file-001.parquet:   0%|      | 0.00/140k [00:00<?, ?B/s]
#
# meta/episodes/chunk-000/file-000.parquet:   0%|     | 0.00/55.5k [00:00<?, ?B/s]
#
#
# stats.json: 13.0kB [00:00, 41.8MB/s]A
#
#
#
# meta/tasks.parquet:   0%|                           | 0.00/2.24k [00:00<?, ?B/s]
#
#
#
# info.json: 3.23kB [00:00, 19.4MB/s]A
#
#
#
# meta/tasks.parquet: 100%|██████████████████| 2.24k/2.24k [00:00<00:00, 7.64kB/s]
#
#
# meta/episodes/chunk-000/file-000.parquet: 100%|█| 55.5k/55.5k [00:00<00:00, 144k
# Fetching 5 files:  20%|█████▍                     | 1/5 [00:00<00:02,  1.76it/s]
# meta/episodes/chunk-000/file-001.parquet: 100%|█| 140k/140k [00:00<00:00, 308kB/
# Fetching 5 files: 100%|███████████████████████████| 5/5 [00:00<00:00,  8.59it/s]
# Fetching 13 files:   0%|                                 | 0/13 [00:00<?, ?it/s]
# data/chunk-000/file-000.parquet:   0%|              | 0.00/69.3k [00:00<?, ?B/s]
#
# data/chunk-000/file-001.parquet:   0%|               | 0.00/603k [00:00<?, ?B/s]
#
#
# videos/observation.images.back/chunk-000(…):   0%|  | 0.00/18.8M [00:00<?, ?B/s]
#
#
#
# videos/observation.images.front/chunk-00(…):   0%|  | 0.00/15.6M [00:00<?, ?B/s]
#
#
#
#
# README.md: 3.72kB [00:00, 15.0MB/s]A
#
#
#
#
#
# videos/observation.images.back/chunk-000(…):   0%|   | 0.00/163M [00:00<?, ?B/s]
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):   0%|   | 0.00/136M [00:00<?, ?B/s]
#
#
#
#
#
#
# .gitattributes: 2.46kB [00:00, 13.2MB/s]A
#
# data/chunk-000/file-000.parquet: 100%|██████| 69.3k/69.3k [00:00<00:00, 613kB/s]
# Fetching 13 files:   8%|█▉                       | 1/13 [00:00<00:04,  2.80it/s]
#
# data/chunk-000/file-001.parquet: 100%|███████| 603k/603k [00:00<00:00, 4.23MB/s]
#
#
#
# videos/observation.images.back/chunk-000(…): 100%|█| 18.8M/18.8M [00:00<00:00, 5
# Fetching 13 files:  77%|██████████████████▍     | 10/13 [00:00<00:00, 19.72it/s]
#
#
#
# videos/observation.images.front/chunk-00(…): 100%|█| 15.6M/15.6M [00:00<00:00, 3
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):   1%| | 1.93M/136M [00:00<00:41, 3.
#
#
#
#
# videos/observation.images.back/chunk-000(…):  18%|▏| 29.2M/163M [00:00<00:03, 35
#
#
#
#
#
# videos/observation.images.front/chunk-00(…):  51%|▌| 69.0M/136M [00:01<00:00, 68
#
#
#
#
# videos/observation.images.back/chunk-000(…): 100%|█| 163M/163M [00:01<00:00, 134
#
#
#
#
#
#
# videos/observation.images.front/chunk-00(…): 100%|█| 136M/136M [00:01<00:00, 104
# Fetching 13 files: 100%|████████████████████████| 13/13 [00:01<00:00,  8.14it/s]
# INFO 2025-12-05 14:16:59 ot_train.py:202 Creating policy
# INFO 2025-12-05 14:17:00 ot_train.py:247 Creating optimizer and scheduler
# INFO 2025-12-05 14:17:00 ot_train.py:259 Output dir: outputs/train/act_greate_akihabara_misson1
# INFO 2025-12-05 14:17:00 ot_train.py:264 cfg.steps=20000 (20K)
# INFO 2025-12-05 14:17:00 ot_train.py:265 dataset.num_frames=17251 (17K)
# INFO 2025-12-05 14:17:00 ot_train.py:266 dataset.num_episodes=30
# INFO 2025-12-05 14:17:00 ot_train.py:269 Effective batch size: 8 x 1 = 8
# INFO 2025-12-05 14:17:00 ot_train.py:270 num_learnable_params=51597190 (52M)
# INFO 2025-12-05 14:17:00 ot_train.py:271 num_total_params=51597190 (52M)
# INFO 2025-12-05 14:17:00 ot_train.py:327 Start offline training on a fixed dataset
# INFO 2025-12-05 14:17:24 ot_train.py:354 step:200 smpl:2K ep:3 epch:0.09 loss:6.348 grdn:154.509 lr:1.0e-05 updt_s:0.118 data_s:0.004
# INFO 2025-12-05 14:17:33 ot_train.py:354 step:400 smpl:3K ep:6 epch:0.19 loss:2.820 grdn:85.388 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:17:42 ot_train.py:354 step:600 smpl:5K ep:8 epch:0.28 loss:2.383 grdn:75.656 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:17:51 ot_train.py:354 step:800 smpl:6K ep:11 epch:0.37 loss:2.124 grdn:68.167 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:18:01 ot_train.py:354 step:1K smpl:8K ep:14 epch:0.46 loss:1.894 grdn:63.239 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:18:10 ot_train.py:354 step:1K smpl:10K ep:17 epch:0.56 loss:1.697 grdn:62.493 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:18:19 ot_train.py:354 step:1K smpl:11K ep:19 epch:0.65 loss:1.512 grdn:60.162 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:18:28 ot_train.py:354 step:2K smpl:13K ep:22 epch:0.74 loss:1.382 grdn:57.637 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:18:37 ot_train.py:354 step:2K smpl:14K ep:25 epch:0.83 loss:1.239 grdn:54.288 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:18:46 ot_train.py:354 step:2K smpl:16K ep:28 epch:0.93 loss:1.122 grdn:51.249 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:20:46 ot_train.py:354 step:2K smpl:18K ep:31 epch:1.02 loss:1.019 grdn:49.118 lr:1.0e-05 updt_s:0.588 data_s:0.009
# INFO 2025-12-05 14:20:55 ot_train.py:354 step:2K smpl:19K ep:33 epch:1.11 loss:0.918 grdn:46.727 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:21:04 ot_train.py:354 step:3K smpl:21K ep:36 epch:1.21 loss:0.832 grdn:44.217 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:21:13 ot_train.py:354 step:3K smpl:22K ep:39 epch:1.30 loss:0.742 grdn:42.227 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:21:22 ot_train.py:354 step:3K smpl:24K ep:42 epch:1.39 loss:0.681 grdn:40.292 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:21:31 ot_train.py:354 step:3K smpl:26K ep:45 epch:1.48 loss:0.619 grdn:39.116 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:21:40 ot_train.py:354 step:3K smpl:27K ep:47 epch:1.58 loss:0.558 grdn:36.251 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:21:50 ot_train.py:354 step:4K smpl:29K ep:50 epch:1.67 loss:0.503 grdn:34.188 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:21:59 ot_train.py:354 step:4K smpl:30K ep:53 epch:1.76 loss:0.454 grdn:33.377 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:22:08 ot_train.py:354 step:4K smpl:32K ep:56 epch:1.85 loss:0.424 grdn:31.268 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:22:17 ot_train.py:354 step:4K smpl:34K ep:58 epch:1.95 loss:0.396 grdn:30.874 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:22:27 ot_train.py:354 step:4K smpl:35K ep:61 epch:2.04 loss:0.355 grdn:29.389 lr:1.0e-05 updt_s:0.044 data_s:0.009
# INFO 2025-12-05 14:22:36 ot_train.py:354 step:5K smpl:37K ep:64 epch:2.13 loss:0.341 grdn:28.038 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:22:46 ot_train.py:354 step:5K smpl:38K ep:67 epch:2.23 loss:0.315 grdn:27.277 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:22:55 ot_train.py:354 step:5K smpl:40K ep:70 epch:2.32 loss:0.295 grdn:26.655 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:22:55 ot_train.py:364 Checkpoint policy after step 5000
# INFO 2025-12-05 14:23:05 ot_train.py:354 step:5K smpl:42K ep:72 epch:2.41 loss:0.278 grdn:25.233 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:23:14 ot_train.py:354 step:5K smpl:43K ep:75 epch:2.50 loss:0.263 grdn:24.424 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:23:23 ot_train.py:354 step:6K smpl:45K ep:78 epch:2.60 loss:0.250 grdn:24.142 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:23:32 ot_train.py:354 step:6K smpl:46K ep:81 epch:2.69 loss:0.242 grdn:23.789 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:23:41 ot_train.py:354 step:6K smpl:48K ep:83 epch:2.78 loss:0.229 grdn:22.578 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:23:50 ot_train.py:354 step:6K smpl:50K ep:86 epch:2.88 loss:0.222 grdn:22.707 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:23:59 ot_train.py:354 step:6K smpl:51K ep:89 epch:2.97 loss:0.211 grdn:21.749 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:24:10 ot_train.py:354 step:7K smpl:53K ep:92 epch:3.06 loss:0.205 grdn:21.322 lr:1.0e-05 updt_s:0.043 data_s:0.010
# INFO 2025-12-05 14:24:19 ot_train.py:354 step:7K smpl:54K ep:95 epch:3.15 loss:0.199 grdn:21.369 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:24:28 ot_train.py:354 step:7K smpl:56K ep:97 epch:3.25 loss:0.194 grdn:21.186 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:24:37 ot_train.py:354 step:7K smpl:58K ep:100 epch:3.34 loss:0.185 grdn:20.428 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:24:46 ot_train.py:354 step:7K smpl:59K ep:103 epch:3.43 loss:0.180 grdn:20.624 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:24:55 ot_train.py:354 step:8K smpl:61K ep:106 epch:3.52 loss:0.178 grdn:20.118 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:25:04 ot_train.py:354 step:8K smpl:62K ep:109 epch:3.62 loss:0.172 grdn:19.956 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:25:13 ot_train.py:354 step:8K smpl:64K ep:111 epch:3.71 loss:0.166 grdn:18.747 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:25:23 ot_train.py:354 step:8K smpl:66K ep:114 epch:3.80 loss:0.164 grdn:18.937 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:25:32 ot_train.py:354 step:8K smpl:67K ep:117 epch:3.90 loss:0.159 grdn:18.352 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:25:41 ot_train.py:354 step:9K smpl:69K ep:120 epch:3.99 loss:0.157 grdn:18.494 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:25:52 ot_train.py:354 step:9K smpl:70K ep:122 epch:4.08 loss:0.153 grdn:18.088 lr:1.0e-05 updt_s:0.044 data_s:0.010
# INFO 2025-12-05 14:26:01 ot_train.py:354 step:9K smpl:72K ep:125 epch:4.17 loss:0.152 grdn:18.214 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:26:10 ot_train.py:354 step:9K smpl:74K ep:128 epch:4.27 loss:0.149 grdn:17.873 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:26:20 ot_train.py:354 step:9K smpl:75K ep:131 epch:4.36 loss:0.144 grdn:18.141 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:26:29 ot_train.py:354 step:10K smpl:77K ep:134 epch:4.45 loss:0.141 grdn:17.293 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:26:38 ot_train.py:354 step:10K smpl:78K ep:136 epch:4.54 loss:0.140 grdn:17.230 lr:1.0e-05 updt_s:0.045 data_s:0.002
# INFO 2025-12-05 14:26:47 ot_train.py:354 step:10K smpl:80K ep:139 epch:4.64 loss:0.135 grdn:17.347 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:26:47 ot_train.py:364 Checkpoint policy after step 10000
# INFO 2025-12-05 14:26:58 ot_train.py:354 step:10K smpl:82K ep:142 epch:4.73 loss:0.135 grdn:16.853 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:27:07 ot_train.py:354 step:10K smpl:83K ep:145 epch:4.82 loss:0.131 grdn:16.235 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:27:16 ot_train.py:354 step:11K smpl:85K ep:147 epch:4.92 loss:0.129 grdn:16.364 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:27:27 ot_train.py:354 step:11K smpl:86K ep:150 epch:5.01 loss:0.129 grdn:16.779 lr:1.0e-05 updt_s:0.044 data_s:0.012
# INFO 2025-12-05 14:27:36 ot_train.py:354 step:11K smpl:88K ep:153 epch:5.10 loss:0.125 grdn:16.334 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:27:45 ot_train.py:354 step:11K smpl:90K ep:156 epch:5.19 loss:0.128 grdn:17.070 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:27:54 ot_train.py:354 step:11K smpl:91K ep:159 epch:5.29 loss:0.123 grdn:16.107 lr:1.0e-05 updt_s:0.043 data_s:0.002
# INFO 2025-12-05 14:28:03 ot_train.py:354 step:12K smpl:93K ep:161 epch:5.38 loss:0.121 grdn:15.924 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:28:13 ot_train.py:354 step:12K smpl:94K ep:164 epch:5.47 loss:0.122 grdn:16.064 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:29:55 ot_train.py:354 step:14K smpl:112K ep:195 epch:6.49 loss:0.105 grdn:14.441 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:30:04 ot_train.py:354 step:14K smpl:114K ep:198 epch:6.59 loss:0.105 grdn:14.698 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:30:13 ot_train.py:354 step:14K smpl:115K ep:200 epch:6.68 loss:0.101 grdn:14.299 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:30:22 ot_train.py:354 step:15K smpl:117K ep:203 epch:6.77 loss:0.100 grdn:14.146 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:30:32 ot_train.py:354 step:15K smpl:118K ep:206 epch:6.86 loss:0.100 grdn:14.119 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:30:41 ot_train.py:354 step:15K smpl:120K ep:209 epch:6.96 loss:0.103 grdn:14.170 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:30:41 ot_train.py:364 Checkpoint policy after step 15000
# INFO 2025-12-05 14:30:53 ot_train.py:354 step:15K smpl:122K ep:211 epch:7.05 loss:0.102 grdn:14.956 lr:1.0e-05 updt_s:0.044 data_s:0.012
# INFO 2025-12-05 14:31:02 ot_train.py:354 step:15K smpl:123K ep:214 epch:7.14 loss:0.099 grdn:13.249 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:31:12 ot_train.py:354 step:16K smpl:125K ep:217 epch:7.23 loss:0.096 grdn:13.705 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:31:21 ot_train.py:354 step:16K smpl:126K ep:220 epch:7.33 loss:0.095 grdn:13.521 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:31:30 ot_train.py:354 step:16K smpl:128K ep:223 epch:7.42 loss:0.096 grdn:13.880 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:31:39 ot_train.py:354 step:16K smpl:130K ep:225 epch:7.51 loss:0.092 grdn:12.890 lr:1.0e-05 updt_s:0.045 data_s:0.002
# INFO 2025-12-05 14:31:48 ot_train.py:354 step:16K smpl:131K ep:228 epch:7.61 loss:0.092 grdn:13.854 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:31:57 ot_train.py:354 step:17K smpl:133K ep:231 epch:7.70 loss:0.093 grdn:14.209 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:32:06 ot_train.py:354 step:17K smpl:134K ep:234 epch:7.79 loss:0.095 grdn:13.468 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:32:16 ot_train.py:354 step:17K smpl:136K ep:237 epch:7.88 loss:0.091 grdn:12.777 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:32:25 ot_train.py:354 step:17K smpl:138K ep:239 epch:7.98 loss:0.091 grdn:13.216 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:32:36 ot_train.py:354 step:17K smpl:139K ep:242 epch:8.07 loss:0.088 grdn:13.513 lr:1.0e-05 updt_s:0.045 data_s:0.012
# INFO 2025-12-05 14:32:45 ot_train.py:354 step:18K smpl:141K ep:245 epch:8.16 loss:0.090 grdn:12.638 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:32:54 ot_train.py:354 step:18K smpl:142K ep:248 epch:8.25 loss:0.086 grdn:13.371 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:03 ot_train.py:354 step:18K smpl:144K ep:250 epch:8.35 loss:0.084 grdn:12.323 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:13 ot_train.py:354 step:18K smpl:146K ep:253 epch:8.44 loss:0.086 grdn:12.757 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:22 ot_train.py:354 step:18K smpl:147K ep:256 epch:8.53 loss:0.084 grdn:12.821 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:31 ot_train.py:354 step:19K smpl:149K ep:259 epch:8.63 loss:0.084 grdn:12.805 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:40 ot_train.py:354 step:19K smpl:150K ep:262 epch:8.72 loss:0.084 grdn:12.761 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:49 ot_train.py:354 step:19K smpl:152K ep:264 epch:8.81 loss:0.082 grdn:11.741 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:33:59 ot_train.py:354 step:19K smpl:154K ep:267 epch:8.90 loss:0.083 grdn:12.466 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:34:08 ot_train.py:354 step:19K smpl:155K ep:270 epch:9.00 loss:0.084 grdn:12.728 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:34:19 ot_train.py:354 step:20K smpl:157K ep:273 epch:9.09 loss:0.079 grdn:12.133 lr:1.0e-05 updt_s:0.044 data_s:0.012
# INFO 2025-12-05 14:34:28 ot_train.py:354 step:20K smpl:158K ep:275 epch:9.18 loss:0.080 grdn:12.423 lr:1.0e-05 updt_s:0.044 data_s:0.002
# INFO 2025-12-05 14:34:38 ot_train.py:354 step:20K smpl:160K ep:278 epch:9.27 loss:0.080 grdn:12.219 lr:1.0e-05 updt_s:0.045 data_s:0.002
# INFO 2025-12-05 14:34:38 ot_train.py:364 Checkpoint policy after step 20000
# INFO 2025-12-05 14:34:39 ot_train.py:435 End of training
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py", line 407, in hf_raise_for_status
#     response.raise_for_status()
#   File "/opt/venv/lib/python3.12/site-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/repos/create
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/venv/bin/lerobot-train", line 7, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 449, in main
#     train()
#   File "/workspace/lerobot/src/lerobot/configs/parser.py", line 233, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/workspace/lerobot/src/lerobot/scripts/lerobot_train.py", line 439, in train
#     unwrapped_policy.push_model_to_hub(cfg)
#   File "/workspace/lerobot/src/lerobot/policies/pretrained.py", line 211, in push_model_to_hub
#     repo_id = api.create_repo(
#               ^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/hf_api.py", line 3779, in create_repo
#     raise err
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/hf_api.py", line 3766, in create_repo
#     hf_raise_for_status(r)
#   File "/opt/venv/lib/python3.12/site-packages/huggingface_hub/utils/_http.py", line 471, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-6932ed7f-7458923977df4c0b01783c62;a8233a6c-d5f5-462b-b6b0-9064f8a124e6)
#
# 403 Forbidden: You don't have the rights to create a model under the namespace "masato-ka".
# Cannot access content at: https://huggingface.co/api/repos/create.
# Make sure your token has the correct permissions.

# %% [markdown]
# **Notes**:
#
# - If using a local dataset, add `--dataset.root=/path/to/dataset`.
# - Adjust `--batch_size` and `--steps` based on your hardware and dataset.
# - Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`
# - Training progress visualized in your wandb dashboard

# %% [markdown]
# ## Upload Checkpoints to Hugging Face
# Now after training is done, upload the last checkpoint. You may refer to [here](https://github.com/huggingface/lerobot/blob/v0.4.0/README.md#add-a-pretrained-policy) for details.

# %%
# !huggingface-cli upload masato-ka/act-greate-akihabara-take2-misson1 outputs/train/act_greate_akihabara_misson1/checkpoints/last/pretrained_model
# e.g. huggingface-cli upload ${HF_USER}/act_so101_3cube_1ksteps \
#  outputs/train/act_so101_3cube_1ksteps/checkpoints/last/pretrained_model
# Out:
# ⚠️  Warning: 'huggingface-cli upload' is deprecated. Use 'hf upload' instead.
# Start hashing 7 files.
# Finished hashing 7 files.
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...d_model/model.safetensors:   0%|              |  782kB /  207MB
#
# Processing Files (0 / 1)      :   0%|              |  782kB /  207MB,   ???B/s
#
# Processing Files (0 / 1)      :   1%|▏             | 2.47MB /  207MB, 8.48MB/s
# New Data Upload               :   1%|▏             | 1.69MB /  134MB, 8.48MB/s
#
# Processing Files (0 / 1)      :  10%|█▎            | 19.9MB /  207MB, 47.8MB/s
# New Data Upload               :   9%|█▎            | 19.1MB /  201MB, 47.8MB/s
#
# Processing Files (0 / 1)      :  43%|█████▉        | 88.2MB /  207MB,  146MB/s
# New Data Upload               :  42%|█████▉        | 87.4MB /  206MB,  146MB/s
#
#
#   ...zer_processor.safetensors:  96%|█████████████▍| 7.25kB / 7.54kB
#
#
#
#   ...zer_processor.safetensors:  96%|█████████████▍| 7.25kB / 7.54kB
#
#   ...d_model/model.safetensors:  83%|███████████▌  |  172MB /  207MB
#
#
#   ...zer_processor.safetensors:  96%|█████████████▍| 7.25kB / 7.54kB
#
#
#
# Processing Files (0 / 3)      :  83%|███████████▌  |  172MB /  207MB,  214MB/s
# New Data Upload               :  83%|███████████▌  |  171MB /  206MB,  214MB/s
#
#   ...d_model/model.safetensors: 100%|█████████████▉|  206MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
# Processing Files (2 / 3)      : 100%|█████████████▉|  206MB /  207MB,  206MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  206MB/s
#
#   ...d_model/model.safetensors: 100%|█████████████▉|  206MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#   ...d_model/model.safetensors: 100%|█████████████▉|  206MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#   ...d_model/model.safetensors: 100%|█████████████▉|  207MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
# Processing Files (2 / 3)      : 100%|█████████████▉|  207MB /  207MB,  129MB/s
# New Data Upload               : 100%|█████████████▉|  206MB /  206MB,  129MB/s
#
#   ...d_model/model.safetensors: 100%|██████████████|  207MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
# Processing Files (3 / 3)      : 100%|██████████████|  207MB /  207MB,  114MB/s
# New Data Upload               : 100%|██████████████|  206MB /  206MB,  114MB/s
#
#   ...d_model/model.safetensors: 100%|██████████████|  207MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#   ...d_model/model.safetensors: 100%|██████████████|  207MB /  207MB
#
#
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#
#
#
# Processing Files (3 / 3)      : 100%|██████████████|  207MB /  207MB,  103MB/s
# New Data Upload               : 100%|██████████████|  206MB /  206MB,  103MB/s
#   ...d_model/model.safetensors: 100%|██████████████|  207MB /  207MB
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
#   ...zer_processor.safetensors: 100%|██████████████| 7.54kB / 7.54kB
# https://huggingface.co/masato-ka/act-greate-akihabara-take2-misson1/tree/main/.

# %% [markdown]
# ## Miscs
# 1. Once the environment is setup, you can open a terminal session for training by navigating to `File → New Launcher → Other → Terminal`.
# 2. You can also upload your datasets to the container by clicking the `Upload Files` button in the left pane.

# %% [markdown]
# ## Q&A
# 1. If you encounter an error like:
#    ```
#    FileExistsError: Output directory outputs/train/act_so101_3cube_1ksteps already exists and resume is False. Please change your output directory so that outputs/train/act_so101_3cube_1ksteps is not overwritten.
#    ```
#    Remove the existing directory before proceeding:

# %%
# !rm -fr outputs/train/act_so101_3cube_1ksteps

# %% [markdown]
# 2. When running models other than ACT, ensure you install the required additional dependencies for those models.

# %%
# For smolVLA
# !cd lerobot && pip install -e ".[smolvla]"
# For Pi
# !cd lerobot && pip install -e ".[pi]"

# %% [markdown]
# 3. If you want to resume the training from last checkpoint, run the command below:

# %%
# !lerobot-train \
  --resume=true \
  --config_path=outputs/train/<job name>/checkpoints/last/pretrained_model/train_config.json \
  --steps=<new total steps>
